# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pymongo

# %%
#read in the csv files and save them as variables

credits_data = "Resources/credits.csv"
titles_data = "Resources/titles.csv"

#create data frames using the newly created variables

credits_data_df = pd.read_csv(credits_data)
titles_data_df = pd.read_csv(titles_data)

# %%
#show part of the credits data dataframe

credits_data_df.head(100)
# Out:
#     person_id       id              name  \
# 0        3748  tm84618    Robert De Niro
# 1       14658  tm84618      Jodie Foster
# 2        7064  tm84618     Albert Brooks
# 3        3739  tm84618     Harvey Keitel
# 4       48933  tm84618   Cybill Shepherd
# ..        ...      ...               ...
# 95      11480  tm70993   Charles McKeown
# 96      11481  tm70993        John Young
# 97      11483  tm70993       Gwen Taylor
# 98      11484  tm70993  Sue Jones-Davies
# 99     548006  tm70993       Peter Brett
#
#                                             character   role
# 0                                       Travis Bickle  ACTOR
# 1                                       Iris Steensma  ACTOR
# 2                                                 Tom  ACTOR
# 3                             Matthew 'Sport' Higgins  ACTOR
# 4                                               Betsy  ACTOR
# ..                                                ...    ...
# 95  False Prophet / Blind Man / Giggling Guard / Stig  ACTOR
# 96               Matthias, Son of Deuteronomy of Gath  ACTOR
# 97                                      Mrs. Big Nose  ACTOR
# 98                                    Judith Iscariot  ACTOR
# 99                                                NaN  ACTOR
#
# [100 rows x 5 columns]

# %%
#show part of the titles data dataframe

titles_data_df.head(20)
# Out:
#           id                                      title   type  \
# 0   ts300399        Five Came Back: The Reference Films   SHOW
# 1    tm84618                                Taxi Driver  MOVIE
# 2   tm127384            Monty Python and the Holy Grail  MOVIE
# 3    tm70993                              Life of Brian  MOVIE
# 4   tm190788                               The Exorcist  MOVIE
# 5    ts22164               Monty Python's Flying Circus   SHOW
# 6    tm14873                                Dirty Harry  MOVIE
# 7   tm185072                               My Fair Lady  MOVIE
# 8    tm98978                            The Blue Lagoon  MOVIE
# 9   tm119281                           Bonnie and Clyde  MOVIE
# 10   tm67378                          The Professionals  MOVIE
# 11   tm44204                       The Guns of Navarone  MOVIE
# 12   tm69778  Lupin the Third: The Castle of Cagliostro  MOVIE
# 13   tm69997             Richard Pryor: Live in Concert  MOVIE
# 14   tm96649                            The Long Riders  MOVIE
# 15   tm16479                            White Christmas  MOVIE
# 16  tm135083                              Cairo Station  MOVIE
# 17   tm14491                                  The Queen  MOVIE
# 18   tm89386                           Hitler: A Career  MOVIE
# 19  tm156453                                        FTA  MOVIE
#
#                                           description  release_year  \
# 0   This collection includes 12 World War II-era p...          1945
# 1   A mentally unstable Vietnam War veteran works ...          1976
# 2   King Arthur, accompanied by his squire, recrui...          1975
# 3   Brian Cohen is an average young Jewish man, bu...          1979
# 4   12-year-old Regan MacNeil begins to adapt an e...          1973
# 5   A British sketch comedy series with the shows ...          1969
# 6   When a madman dubbed 'Scorpio' terrorizes San ...          1971
# 7   A snobbish phonetics professor agrees to a wag...          1964
# 8   Two small children and a ship's cook survive a...          1980
# 9   In the 1930s, bored waitress Bonnie Parker fal...          1967
# 10  An arrogant Texas millionaire hires four adven...          1966
# 11  A team of allied saboteurs are assigned an imp...          1961
# 12  After a successful robbery leaves famed thief ...          1979
# 13  Richard Pryor delivers monologues on race, sex...          1979
# 14  The origins, exploits and the ultimate fate of...          1980
# 15  Two talented song-and-dance men team up after ...          1954
# 16  Qinawi, a physically challenged peddler who ma...          1958
# 17  In 1967, New York City is host to the Miss All...          1968
# 18  A keen chronicle of the unlikely rise to power...          1977
# 19  A documentary about a political troupe headed ...          1972
#
#    age_certification  runtime  \
# 0              TV-MA       48
# 1                  R      113
# 2                 PG       91
# 3                  R       94
# 4                  R      133
# 5              TV-14       30
# 6                  R      102
# 7                  G      170
# 8                  R      104
# 9                  R      110
# 10             PG-13      117
# 11               NaN      158
# 12                PG      100
# 13                 R       78
# 14                 R       99
# 15               NaN      115
# 16               NaN       77
# 17               NaN       68
# 18                PG      150
# 19                 R       97
#
#                                                genres production_countries  \
# 0                                   ['documentation']               ['US']
# 1                                  ['crime', 'drama']               ['US']
# 2                               ['comedy', 'fantasy']               ['GB']
# 3                                          ['comedy']               ['GB']
# 4                                          ['horror']               ['US']
# 5                              ['comedy', 'european']               ['GB']
# 6                     ['thriller', 'crime', 'action']               ['US']
# 7             ['drama', 'music', 'romance', 'family']               ['US']
# 8                                ['romance', 'drama']               ['US']
# 9                        ['drama', 'crime', 'action']               ['US']
# 10                  ['western', 'action', 'european']               ['US']
# 11                         ['war', 'action', 'drama']         ['US', 'GB']
# 12  ['comedy', 'animation', 'action', 'fantasy', '...               ['JP']
# 13                        ['comedy', 'documentation']               ['US']
# 14                               ['western', 'crime']               ['US']
# 15                     ['romance', 'comedy', 'music']               ['US']
# 16                       ['drama', 'crime', 'comedy']               ['EG']
# 17                                  ['documentation']               ['US']
# 18           ['documentation', 'history', 'european']               ['DE']
# 19               ['comedy', 'documentation', 'music']               ['US']
#
#     seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0       1.0        NaN         NaN         NaN            0.600         NaN
# 1       NaN  tt0075314         8.3    795222.0           27.612         8.2
# 2       NaN  tt0071853         8.2    530877.0           18.216         7.8
# 3       NaN  tt0079470         8.0    392419.0           17.505         7.8
# 4       NaN  tt0070047         8.1    391942.0           95.337         7.7
# 5       4.0  tt0063929         8.8     72895.0           12.919         8.3
# 6       NaN  tt0066999         7.7    153463.0           14.745         7.5
# 7       NaN  tt0058385         7.8     94121.0           15.949         7.6
# 8       NaN  tt0080453         5.8     69053.0           44.038         6.2
# 9       NaN  tt0061418         7.7    111189.0           15.309         7.5
# 10      NaN  tt0060862         7.3     16168.0           12.155         7.1
# 11      NaN  tt0054953         7.5     50150.0           15.405         7.4
# 12      NaN  tt0079833         7.6     30277.0           14.008         7.5
# 13      NaN  tt0079807         8.1      5141.0            4.681         7.5
# 14      NaN  tt0081071         6.9     11329.0            8.808         6.6
# 15      NaN  tt0047673         7.5     42373.0            9.710         7.2
# 16      NaN  tt0051390         7.5      4385.0            3.556         7.4
# 17      NaN  tt0183686         7.2      1117.0            2.419         6.5
# 18      NaN  tt0191182         7.5      2416.0            9.305         7.4
# 19      NaN  tt0068562         6.2       411.0            2.466         6.1

# %%
#remove special characters in the genres column

spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–"]

for char in spec_chars:
    titles_data_df['genres'] = titles_data_df['genres'].str.replace(char, ' ')

# %% [markdown]
# # Titles Data Cleaning

# %%
# Remove unecessary columns from the DataFrame and save titles_data_df to a new DataFrame

reduced_titles_data_df = titles_data_df[["id", "title", "type", "release_year", "age_certification", 
                                         "runtime", "genres", "imdb_id", "imdb_score",
                                        "imdb_votes", "tmdb_popularity", "tmdb_score"]]

#show the titles_data_df dataframe

reduced_titles_data_df.head(20)
# Out:
#           id                                      title   type  release_year  \
# 0   ts300399        Five Came Back: The Reference Films   SHOW          1945
# 1    tm84618                                Taxi Driver  MOVIE          1976
# 2   tm127384            Monty Python and the Holy Grail  MOVIE          1975
# 3    tm70993                              Life of Brian  MOVIE          1979
# 4   tm190788                               The Exorcist  MOVIE          1973
# 5    ts22164               Monty Python's Flying Circus   SHOW          1969
# 6    tm14873                                Dirty Harry  MOVIE          1971
# 7   tm185072                               My Fair Lady  MOVIE          1964
# 8    tm98978                            The Blue Lagoon  MOVIE          1980
# 9   tm119281                           Bonnie and Clyde  MOVIE          1967
# 10   tm67378                          The Professionals  MOVIE          1966
# 11   tm44204                       The Guns of Navarone  MOVIE          1961
# 12   tm69778  Lupin the Third: The Castle of Cagliostro  MOVIE          1979
# 13   tm69997             Richard Pryor: Live in Concert  MOVIE          1979
# 14   tm96649                            The Long Riders  MOVIE          1980
# 15   tm16479                            White Christmas  MOVIE          1954
# 16  tm135083                              Cairo Station  MOVIE          1958
# 17   tm14491                                  The Queen  MOVIE          1968
# 18   tm89386                           Hitler: A Career  MOVIE          1977
# 19  tm156453                                        FTA  MOVIE          1972
#
#    age_certification  runtime  \
# 0              TV-MA       48
# 1                  R      113
# 2                 PG       91
# 3                  R       94
# 4                  R      133
# 5              TV-14       30
# 6                  R      102
# 7                  G      170
# 8                  R      104
# 9                  R      110
# 10             PG-13      117
# 11               NaN      158
# 12                PG      100
# 13                 R       78
# 14                 R       99
# 15               NaN      115
# 16               NaN       77
# 17               NaN       68
# 18                PG      150
# 19                 R       97
#
#                                                genres    imdb_id  imdb_score  \
# 0                                     documentation          NaN         NaN
# 1                                    crime    drama    tt0075314         8.3
# 2                                 comedy    fantasy    tt0071853         8.2
# 3                                            comedy    tt0079470         8.0
# 4                                            horror    tt0070047         8.1
# 5                                comedy    european    tt0063929         8.8
# 6                       thriller    crime    action    tt0066999         7.7
# 7               drama    music    romance    family    tt0058385         7.8
# 8                                  romance    drama    tt0080453         5.8
# 9                          drama    crime    action    tt0061418         7.7
# 10                    western    action    european    tt0060862         7.3
# 11                           war    action    drama    tt0054953         7.5
# 12    comedy    animation    action    fantasy    ...  tt0079833         7.6
# 13                          comedy    documentation    tt0079807         8.1
# 14                                 western    crime    tt0081071         6.9
# 15                       romance    comedy    music    tt0047673         7.5
# 16                         drama    crime    comedy    tt0051390         7.5
# 17                                    documentation    tt0183686         7.2
# 18             documentation    history    european    tt0191182         7.5
# 19                 comedy    documentation    music    tt0068562         6.2
#
#     imdb_votes  tmdb_popularity  tmdb_score
# 0          NaN            0.600         NaN
# 1     795222.0           27.612         8.2
# 2     530877.0           18.216         7.8
# 3     392419.0           17.505         7.8
# 4     391942.0           95.337         7.7
# 5      72895.0           12.919         8.3
# 6     153463.0           14.745         7.5
# 7      94121.0           15.949         7.6
# 8      69053.0           44.038         6.2
# 9     111189.0           15.309         7.5
# 10     16168.0           12.155         7.1
# 11     50150.0           15.405         7.4
# 12     30277.0           14.008         7.5
# 13      5141.0            4.681         7.5
# 14     11329.0            8.808         6.6
# 15     42373.0            9.710         7.2
# 16      4385.0            3.556         7.4
# 17      1117.0            2.419         6.5
# 18      2416.0            9.305         7.4
# 19       411.0            2.466         6.1

# %%
#check to see if there are any rows with missing data
reduced_titles_data_df.count()
# Out:
# id                   5806
# title                5805
# type                 5806
# release_year         5806
# age_certification    3196
# runtime              5806
# genres               5806
# imdb_id              5362
# imdb_score           5283
# imdb_votes           5267
# tmdb_popularity      5712
# tmdb_score           5488
# dtype: int64

# %%
#remove the rows with missing data and check again with .count()

new_titles_data_df = reduced_titles_data_df.dropna(how="any")
new_titles_data_df.count()
# Out:
# id                   2900
# title                2900
# type                 2900
# release_year         2900
# age_certification    2900
# runtime              2900
# genres               2900
# imdb_id              2900
# imdb_score           2900
# imdb_votes           2900
# tmdb_popularity      2900
# tmdb_score           2900
# dtype: int64

# %%
#show new_titles_data_df

new_titles_data_df.head(10)
# Out:
#           id                            title   type  release_year  \
# 1    tm84618                      Taxi Driver  MOVIE          1976
# 2   tm127384  Monty Python and the Holy Grail  MOVIE          1975
# 3    tm70993                    Life of Brian  MOVIE          1979
# 4   tm190788                     The Exorcist  MOVIE          1973
# 5    ts22164     Monty Python's Flying Circus   SHOW          1969
# 6    tm14873                      Dirty Harry  MOVIE          1971
# 7   tm185072                     My Fair Lady  MOVIE          1964
# 8    tm98978                  The Blue Lagoon  MOVIE          1980
# 9   tm119281                 Bonnie and Clyde  MOVIE          1967
# 10   tm67378                The Professionals  MOVIE          1966
#
#    age_certification  runtime                                   genres  \
# 1                  R      113                         crime    drama
# 2                 PG       91                      comedy    fantasy
# 3                  R       94                                 comedy
# 4                  R      133                                 horror
# 5              TV-14       30                     comedy    european
# 6                  R      102            thriller    crime    action
# 7                  G      170    drama    music    romance    family
# 8                  R      104                       romance    drama
# 9                  R      110               drama    crime    action
# 10             PG-13      117          western    action    european
#
#       imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1   tt0075314         8.3    795222.0           27.612         8.2
# 2   tt0071853         8.2    530877.0           18.216         7.8
# 3   tt0079470         8.0    392419.0           17.505         7.8
# 4   tt0070047         8.1    391942.0           95.337         7.7
# 5   tt0063929         8.8     72895.0           12.919         8.3
# 6   tt0066999         7.7    153463.0           14.745         7.5
# 7   tt0058385         7.8     94121.0           15.949         7.6
# 8   tt0080453         5.8     69053.0           44.038         6.2
# 9   tt0061418         7.7    111189.0           15.309         7.5
# 10  tt0060862         7.3     16168.0           12.155         7.1

# %%
#Filter the dataframe so that it only has Movie data
only_movies_df = new_titles_data_df.loc[new_titles_data_df["type"] == "MOVIE", :]
only_movies_df
# Out:
#              id                             title   type  release_year  \
# 1       tm84618                       Taxi Driver  MOVIE          1976
# 2      tm127384   Monty Python and the Holy Grail  MOVIE          1975
# 3       tm70993                     Life of Brian  MOVIE          1979
# 4      tm190788                      The Exorcist  MOVIE          1973
# 6       tm14873                       Dirty Harry  MOVIE          1971
# ...         ...                               ...    ...           ...
# 5692   tm983722                        Prime Time  MOVIE          2021
# 5699   tm855340                         Thalaivii  MOVIE          2021
# 5704  tm1099320  Convergence: Courage in a Crisis  MOVIE          2021
# 5713  tm1120766                            Angèle  MOVIE          2021
# 5773   tm982470                       Stuck Apart  MOVIE          2021
#
#      age_certification  runtime                           genres     imdb_id  \
# 1                    R      113                 crime    drama     tt0075314
# 2                   PG       91              comedy    fantasy     tt0071853
# 3                    R       94                         comedy     tt0079470
# 4                    R      133                         horror     tt0070047
# 6                    R      102    thriller    crime    action     tt0066999
# ...                ...      ...                              ...         ...
# 5692                 R       93              thriller    drama    tt11460976
# 5699                 G      153                          drama    tt10152736
# 5704                 R      113                  documentation    tt15398694
# 5713                 R       84         music    documentation    tt15820298
# 5773                 R       96                comedy    drama    tt11213372
#
#       imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1            8.3    795222.0           27.612         8.2
# 2            8.2    530877.0           18.216         7.8
# 3            8.0    392419.0           17.505         7.8
# 4            8.1    391942.0           95.337         7.7
# 6            7.7    153463.0           14.745         7.5
# ...          ...         ...              ...         ...
# 5692         5.2      1757.0           13.364         5.1
# 5699         5.9     30439.0            5.557         5.8
# 5704         5.4       252.0            9.258         5.2
# 5713         7.0       493.0            5.362         7.1
# 5773         6.0     10418.0            7.403         6.1
#
# [1302 rows x 12 columns]

# %%
graph_titles_df = only_movies_df[["title", "genres", "imdb_score"]]
graph_titles_df
# Out:
#                                  title                           genres  \
# 1                          Taxi Driver                 crime    drama
# 2      Monty Python and the Holy Grail              comedy    fantasy
# 3                        Life of Brian                         comedy
# 4                         The Exorcist                         horror
# 6                          Dirty Harry    thriller    crime    action
# ...                                ...                              ...
# 5692                        Prime Time              thriller    drama
# 5699                         Thalaivii                          drama
# 5704  Convergence: Courage in a Crisis                  documentation
# 5713                            Angèle         music    documentation
# 5773                       Stuck Apart                comedy    drama
#
#       imdb_score
# 1            8.3
# 2            8.2
# 3            8.0
# 4            8.1
# 6            7.7
# ...          ...
# 5692         5.2
# 5699         5.9
# 5704         5.4
# 5713         7.0
# 5773         6.0
#
# [1302 rows x 3 columns]

# %%
#We need to first separate the values in the genres into multiple columns

graph_titles_df1 = graph_titles_df['genres'].str.split(',', expand=True)
graph_titles_df1
# Out:
#                                     0
# 1                    crime    drama
# 2                 comedy    fantasy
# 3                            comedy
# 4                            horror
# 6       thriller    crime    action
# ...                               ...
# 5692              thriller    drama
# 5699                          drama
# 5704                  documentation
# 5713         music    documentation
# 5773                comedy    drama
#
# [1302 rows x 1 columns]

# %%
#show all the genre types within the genres column
new_graph_titles_df1 = graph_titles_df1.dropna(how='any')
new_graph_titles_df1
# Out:
#                                     0
# 1                    crime    drama
# 2                 comedy    fantasy
# 3                            comedy
# 4                            horror
# 6       thriller    crime    action
# ...                               ...
# 5692              thriller    drama
# 5699                          drama
# 5704                  documentation
# 5713         music    documentation
# 5773                comedy    drama
#
# [1302 rows x 1 columns]

# %%
genre_list = ['action', 'family', 'animation', 
              'history', 'scifi', 'romance', 'comedy', 'fantasy', 
              'horror', 'drama', 'scifi', 'thriller', 'music', 'sport', 'documentation']

# %%
better_titles_data_df = titles_data_df[["id", "title", "release_year", 
                                          "genres", "imdb_score",
                                        "imdb_votes","tmdb_score"]]

best_titles_data_df = better_titles_data_df.dropna(how="any")

best_titles_data_df
# Out:
#              id                               title  release_year  \
# 1       tm84618                         Taxi Driver          1976
# 2      tm127384     Monty Python and the Holy Grail          1975
# 3       tm70993                       Life of Brian          1979
# 4      tm190788                        The Exorcist          1973
# 5       ts22164        Monty Python's Flying Circus          1969
# ...         ...                                 ...           ...
# 5792  tm1097142                            My Bride          2021
# 5795   tm878575                 The Heartbreak Club          2021
# 5796   ts286386                         The Big Day          2021
# 5798  tm1004011                       Time to Dance          2021
# 5805   ts271048  Mighty Little Bheem: Kite Festival          2021
#
#                                  genres  imdb_score  imdb_votes  tmdb_score
# 1                      crime    drama           8.3    795222.0         8.2
# 2                   comedy    fantasy           8.2    530877.0         7.8
# 3                              comedy           8.0    392419.0         7.8
# 4                              horror           8.1    391942.0         7.7
# 5                  comedy    european           8.8     72895.0         8.3
# ...                                 ...         ...         ...         ...
# 5792       comedy    drama    romance           4.9       281.0         5.3
# 5795       comedy    drama    romance           6.2       188.0         8.0
# 5796               reality    romance           4.6       327.0         6.0
# 5798                 drama    romance           2.2       950.0         4.0
# 5805    family    comedy    animation           8.8        16.0        10.0
#
# [5041 rows x 7 columns]

# %%
#We need to first separate the values in the genres into multiple columns

graph_titles_df1 = graph_titles_df['genres'].str.split(expand=True)
graph_titles_df1
# Out:
#                   0              1       2     3     4     5     6     7
# 1             crime          drama    None  None  None  None  None  None
# 2            comedy        fantasy    None  None  None  None  None  None
# 3            comedy           None    None  None  None  None  None  None
# 4            horror           None    None  None  None  None  None  None
# 6          thriller          crime  action  None  None  None  None  None
# ...             ...            ...     ...   ...   ...   ...   ...   ...
# 5692       thriller          drama    None  None  None  None  None  None
# 5699          drama           None    None  None  None  None  None  None
# 5704  documentation           None    None  None  None  None  None  None
# 5713          music  documentation    None  None  None  None  None  None
# 5773         comedy          drama    None  None  None  None  None  None
#
# [1302 rows x 8 columns]

# %%
cleaner_genre_df = pd.DataFrame(graph_titles_df1[0])
cleanest_genre_df = cleaner_genre_df.rename(columns={0:"Genre"})
cleanest_genre_df
# Out:
#               Genre
# 1             crime
# 2            comedy
# 3            comedy
# 4            horror
# 6          thriller
# ...             ...
# 5692       thriller
# 5699          drama
# 5704  documentation
# 5713          music
# 5773         comedy
#
# [1302 rows x 1 columns]

# %%
#count how many of each genre
count_genre = cleanest_genre_df.value_counts()

#insert genre count into bar chart
genre_chart = count_genre.plot(kind='bar')

#set the x and y labels
genre_chart.set_xlabel("Genres")
genre_chart.set_ylabel("Number of Genres")

plt.show()

# %%
cleanest_genre_df.value_counts()
# Out:
# Genre
# drama            309
# comedy           302
# thriller         195
# romance           77
# fantasy           76
# documentation     65
# horror            58
# action            55
# crime             46
# scifi             42
# animation         35
# western           13
# family            13
# music             12
# war                3
# history            1
# dtype: int64

# %% [markdown]
# ## Genres Data Graphs

# %%
zx_titles_data = "Resources/zx_titles.csv"

zx_titles_df = pd.read_csv(zx_titles_data, encoding='latin-1')

zx_titles_df
# Out:
#        key                             title         genres  imdb_score
# 0        1                       Taxi Driver          crime         8.3
# 1        1                       Taxi Driver          drama         8.3
# 2        2   Monty Python and the Holy Grail         comedy         8.2
# 3        2   Monty Python and the Holy Grail        fantasy         8.2
# 4        3                     Life of Brian         comedy         8.0
# ...    ...                               ...            ...         ...
# 3785  5704  Convergence: Courage in a Crisis  documentation         5.4
# 3786  5713                            Angèle          music         7.0
# 3787  5713                            Angèle  documentation         7.0
# 3788  5773                       Stuck Apart         comedy         6.0
# 3789  5773                       Stuck Apart          drama         6.0
#
# [3790 rows x 4 columns]

# %%
#Turn Genre List into a DataFrame for easy viewing to complete next part

unique_genre_list = zx_titles_df['genres'].unique()

genre_list_df = pd.DataFrame(unique_genre_list)
genre_list_df
# Out:
#                 0
# 0           crime
# 1           drama
# 2          comedy
# 3         fantasy
# 4          horror
# 5        thriller
# 6          action
# 7           music
# 8         romance
# 9          family
# 10        western
# 11       european
# 12      animation
# 13  documentation
# 14        history
# 15          scifi
# 16            war
# 17          sport
# 18        reality

# %%
max_x = zx_titles_df.loc[zx_titles_df['imdb_score'].idxmax()]
print(max_x)
# Out:
# key                                            876
# title         Chhota Bheem & Krishna in Mayanagari
# genres                                   animation
# imdb_score                                       9
# Name: 1201, dtype: object

# %%
#Create filters to separate the movies by genre

#Action Genre DataFrame
only_action_df = zx_titles_df.loc[zx_titles_df["genres"] == "action", :]

#Family Genre DataFrame
only_family_df = zx_titles_df.loc[zx_titles_df["genres"] == "family", :]

#Animation Genre DataFrame
only_animation_df = zx_titles_df.loc[zx_titles_df["genres"] == "animation", :]

#History Genre DataFrame
only_history_df = zx_titles_df.loc[zx_titles_df["genres"] == "history", :]

#Scifi Genre DataFrame
only_scifi_df = zx_titles_df.loc[zx_titles_df["genres"] == "scifi", :]

#Romance Genre DataFrame
only_romance_df = zx_titles_df.loc[zx_titles_df["genres"] == "romance", :]

#Comedy Genre DataFrame
only_comedy_df = zx_titles_df.loc[zx_titles_df["genres"] == "comedy", :]

#Fantasy Genre DataFrame
only_fantasy_df = zx_titles_df.loc[zx_titles_df["genres"] == "fantasy", :]

#Horror Genre DataFrame
only_horror_df = zx_titles_df.loc[zx_titles_df["genres"] == "horror", :]

#Drama Genre DataFrame
only_drama_df = zx_titles_df.loc[zx_titles_df["genres"] == "drama", :]

#Thriller Genre DataFrame
only_thriller_df = zx_titles_df.loc[zx_titles_df["genres"] == "thriller", :]

#Music Genre DataFrame
only_music_df = zx_titles_df.loc[zx_titles_df["genres"] == "music", :]

#Scifi Genre DataFrame
only_sport_df = zx_titles_df.loc[zx_titles_df["genres"] == "sport", :]

#Western Genre DataFrame
only_western_df = zx_titles_df.loc[zx_titles_df["genres"] == "western", :]

#European Genre DataFrame
only_european_df = zx_titles_df.loc[zx_titles_df["genres"] == "european", :]

#War Genre DataFrame
only_war_df = zx_titles_df.loc[zx_titles_df["genres"] == "war", :]

# %%
only_action_df
# Out:
#        key                                      title  genres  imdb_score
# 8        6                                Dirty Harry  action         7.7
# 17       9                           Bonnie and Clyde  action         7.7
# 19      10                          The Professionals  action         7.3
# 23      12  Lupin the Third: The Castle of Cagliostro  action         7.6
# 37      46                                    Top Gun  action         6.9
# ...    ...                                        ...     ...         ...
# 3655  5249                       The Loud House Movie  action         6.2
# 3682  5299                Mobile Suit Gundam Hathaway  action         6.6
# 3704  5405                           Dynasty Warriors  action         4.7
# 3707  5425                       Bright: Samurai Soul  action         5.5
# 3750  5535                                      Amina  action         3.9
#
# [341 rows x 4 columns]

# %%
#Store Averages for each Movie Genre imdb_score in unique variables

action_average = only_action_df["imdb_score"].mean()
print(float(action_average))
# Out:
# 6.228445747800587

# %%
#Calculate Averages for Each Genre

genre_group = zx_titles_df.groupby(["genres"])

g_imdb_scores_averages = genre_group.mean()

g_imdb_scores_averages_df = pd.DataFrame(g_imdb_scores_averages)

g_imdb_scores_averages_df
# Out:
#                        key  imdb_score
# genres
# action         1931.856305    6.228446
# animation      2266.179104    6.532836
# comedy         2075.392989    6.222509
# crime          2062.388889    6.411111
# documentation  2866.106870    6.933588
# drama          2065.392857    6.532967
# european       1559.241071    6.514286
# family         2213.333333    6.118391
# fantasy        1894.631579    6.258421
# history        2265.203390    7.033898
# horror         1840.563492    5.765873
# music          2807.396226    6.743396
# reality        4022.666667    7.533333
# romance        1852.122222    6.301481
# scifi          2266.325758    5.978788
# sport          2436.258065    6.454839
# thriller       2005.491400    6.198280
# war            1717.470588    6.945098
# western        1620.000000    6.700000

# %%
reduced_imdb_scores_average_df = g_imdb_scores_averages_df[["imdb_score"]]
reduced_imdb_scores_average_df
# Out:
#                imdb_score
# genres
# action           6.228446
# animation        6.532836
# comedy           6.222509
# crime            6.411111
# documentation    6.933588
# drama            6.532967
# european         6.514286
# family           6.118391
# fantasy          6.258421
# history          7.033898
# horror           5.765873
# music            6.743396
# reality          7.533333
# romance          6.301481
# scifi            5.978788
# sport            6.454839
# thriller         6.198280
# war              6.945098
# western          6.700000

# %%
#insert imdb average scores into a bar chart
reduced_imdb_scores_average_df.plot(kind='bar', figsize= (11, 5), color='green')

#set the x and y labels
plt.xlabel("Genres")
plt.ylabel("Average IMDB Score")

plt.tight_layout()
plt.show()

# %%
zx_titles_df.value_counts(['genres'])
# Out:
# genres
# drama            728
# comedy           542
# thriller         407
# action           341
# romance          270
# crime            252
# fantasy          190
# family           174
# animation        134
# scifi            132
# documentation    131
# horror           126
# european         112
# sport             62
# history           59
# music             53
# war               51
# western           23
# reality            3
# dtype: int64

# %%
#insert genre count into bar chart
genre_chart_count = zx_titles_df.value_counts(['genres'])

genre_chart_2 = genre_chart_count.plot(kind='bar')

#set the x and y labels
genre_chart_2.set_xlabel("Genres")
genre_chart_2.set_ylabel("Number of Genres")

plt.tight_layout()
plt.show()

# %%
g_imdb_scores_median = genre_group["imdb_score"].median()
g_imdb_scores_median_df = pd.DataFrame(g_imdb_scores_median)
g_imdb_scores_median_df
# Out:
#                imdb_score
# genres
# action               6.30
# animation            6.60
# comedy               6.20
# crime                6.40
# documentation        7.10
# drama                6.60
# european             6.70
# family               6.20
# fantasy              6.40
# history              7.10
# horror               5.75
# music                6.80
# reality              7.70
# romance              6.30
# scifi                6.00
# sport                6.75
# thriller             6.30
# war                  7.00
# western              6.90

# %%
#graph the imdb score median
g_imdb_scores_median_df.plot(kind='bar', figsize= (11, 5), color='orange')

#set the x and y labels
plt.xlabel("Genres")
plt.ylabel("Average IMDB Score")

plt.tight_layout()
plt.show()

# %%
#export the graph DataFrames to csv's

reduced_imdb_scores_average_df.to_csv('Resources/IMDB_Average_Score_1.csv')
g_imdb_scores_median_df.to_csv('Resources/IMDB_Median_Score_1.csv')

# %% [markdown]
# ## Mongo DB

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

titles_db = client.six_three_db

# %%
titles_collection = titles_db.titles.find_one()

# %%
results = titles_db.titles.find()
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('6311590052336cecf29f8906'), 'id': 'ts300399', 'title': 'Five Came Back: The Reference Films', 'type': 'SHOW', 'description': 'This collection includes 12 World War II-era propaganda films — many of which are graphic and offensive — discussed in the docuseries "Five Came Back."', 'release_year': '1945', 'age_certification': 'TV-MA', 'runtime': '48', 'genres': "['documentation']", 'production_countries': "['US']", 'seasons': '1.0', 'tmdb_popularity': '0.6', 'genres_array': ['documentation'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8907'), 'id': 'tm84618', 'title': 'Taxi Driver', 'type': 'MOVIE', 'description': 'A mentally unstable Vietnam War veteran works as a night-time taxi driver in New York City where the perceived decadence and sleaze feed his urge for violent action, attempting to save a preadolescent prostitute in the process.', 'release_year': '1976', 'age_certification': 'R', 'runtime': '113', 'genres': "['crime', 'drama']", 'production_countries': "['US']", 'imdb_id': 'tt0075314', 'imdb_score': '8.3', 'imdb_votes': '795222.0', 'tmdb_popularity': '27.612', 'tmdb_score': '8.2', 'genres_array': ['crime', 'drama'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8908'), 'id': 'tm127384', 'title': 'Monty Python and the Holy Grail', 'type': 'MOVIE', 'description': 'King Arthur, accompanied by his squire, recruits his Knights of the Round Table, including Sir Bedevere the Wise, Sir Lancelot the Brave, Sir Robin the Not-Quite-So-Brave-As-Sir-Lancelot and Sir Galahad the Pure. On the way, Arthur battles the Black Knight who, despite having had all his limbs chopped off, insists he can still fight. They reach Camelot, but Arthur decides not  to enter, as "it is a silly place".', 'release_year': '1975', 'age_certification': 'PG', 'runtime': '91', 'genres': "['comedy', 'fantasy']", 'production_countries': "['GB']", 'imdb_id': 'tt0071853', 'imdb_score': '8.2', 'imdb_votes': '530877.0', 'tmdb_popularity': '18.216', 'tmdb_score': '7.8', 'genres_array': ['comedy', 'fantasy'], 'production_countries_array': ['GB']}
# {'_id': ObjectId('6311590052336cecf29f8909'), 'id': 'tm70993', 'title': 'Life of Brian', 'type': 'MOVIE', 'description': "Brian Cohen is an average young Jewish man, but through a series of ridiculous events, he gains a reputation as the Messiah. When he's not dodging his followers or being scolded by his shrill mother, the hapless Brian has to contend with the pompous Pontius Pilate and acronym-obsessed members of a separatist movement. Rife with Monty Python's signature absurdity, the tale finds Brian's life paralleling Biblical lore, albeit with many more laughs.", 'release_year': '1979', 'age_certification': 'R', 'runtime': '94', 'genres': "['comedy']", 'production_countries': "['GB']", 'imdb_id': 'tt0079470', 'imdb_score': '8.0', 'imdb_votes': '392419.0', 'tmdb_popularity': '17.505', 'tmdb_score': '7.8', 'genres_array': ['comedy'], 'production_countries_array': ['GB']}
# {'_id': ObjectId('6311590052336cecf29f890a'), 'id': 'tm190788', 'title': 'The Exorcist', 'type': 'MOVIE', 'description': '12-year-old Regan MacNeil begins to adapt an explicit new personality as strange events befall the local area of Georgetown. Her mother becomes torn between science and superstition in a desperate bid to save her daughter, and ultimately turns to her last hope: Father Damien Karras, a troubled priest who is struggling with his own faith.', 'release_year': '1973', 'age_certification': 'R', 'runtime': '133', 'genres': "['horror']", 'production_countries': "['US']", 'imdb_id': 'tt0070047', 'imdb_score': '8.1', 'imdb_votes': '391942.0', 'tmdb_popularity': '95.337', 'tmdb_score': '7.7', 'genres_array': ['horror'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f890b'), 'id': 'ts22164', 'title': "Monty Python's Flying Circus", 'type': 'SHOW', 'description': 'A British sketch comedy series with the shows being composed of surreality, risqué or innuendo-laden humour, sight gags and observational sketches without punchlines.', 'release_year': '1969', 'age_certification': 'TV-14', 'runtime': '30', 'genres': "['comedy', 'european']", 'production_countries': "['GB']", 'seasons': '4.0', 'imdb_id': 'tt0063929', 'imdb_score': '8.8', 'imdb_votes': '72895.0', 'tmdb_popularity': '12.919', 'tmdb_score': '8.3', 'genres_array': ['comedy', 'european'], 'production_countries_array': ['GB']}
# {'_id': ObjectId('6311590052336cecf29f890c'), 'id': 'tm14873', 'title': 'Dirty Harry', 'type': 'MOVIE', 'description': "When a madman dubbed 'Scorpio' terrorizes San Francisco, hard-nosed cop, Harry Callahan – famous for his take-no-prisoners approach to law enforcement – is tasked with hunting down the psychopath. Harry eventually collars Scorpio in the process of rescuing a kidnap victim, only to see him walk on technicalities. Now, the maverick detective is determined to nail the maniac himself.", 'release_year': '1971', 'age_certification': 'R', 'runtime': '102', 'genres': "['thriller', 'crime', 'action']", 'production_countries': "['US']", 'imdb_id': 'tt0066999', 'imdb_score': '7.7', 'imdb_votes': '153463.0', 'tmdb_popularity': '14.745', 'tmdb_score': '7.5', 'genres_array': ['thriller', 'crime', 'action'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f890d'), 'id': 'tm185072', 'title': 'My Fair Lady', 'type': 'MOVIE', 'description': 'A snobbish phonetics professor agrees to a wager that he can take a flower girl and make her presentable in high society.', 'release_year': '1964', 'age_certification': 'G', 'runtime': '170', 'genres': "['drama', 'music', 'romance', 'family']", 'production_countries': "['US']", 'imdb_id': 'tt0058385', 'imdb_score': '7.8', 'imdb_votes': '94121.0', 'tmdb_popularity': '15.949', 'tmdb_score': '7.6', 'genres_array': ['drama', 'music', 'romance', 'family'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f890e'), 'id': 'tm98978', 'title': 'The Blue Lagoon', 'type': 'MOVIE', 'description': "Two small children and a ship's cook survive a shipwreck and find safety on an idyllic tropical island. Soon, however, the cook dies and the young boy and girl are left on their own. Days become years and Emmeline and Richard make a home for themselves surrounded by exotic creatures and nature's beauty. But will they ever see civilization again?", 'release_year': '1980', 'age_certification': 'R', 'runtime': '104', 'genres': "['romance', 'drama']", 'production_countries': "['US']", 'imdb_id': 'tt0080453', 'imdb_score': '5.8', 'imdb_votes': '69053.0', 'tmdb_popularity': '44.038', 'tmdb_score': '6.2', 'genres_array': ['romance', 'drama'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f890f'), 'id': 'tm119281', 'title': 'Bonnie and Clyde', 'type': 'MOVIE', 'description': 'In the 1930s, bored waitress Bonnie Parker falls in love with an ex-con named Clyde Barrow and together they start a violent crime spree through the country, stealing cars and robbing banks.', 'release_year': '1967', 'age_certification': 'R', 'runtime': '110', 'genres': "['drama', 'crime', 'action']", 'production_countries': "['US']", 'imdb_id': 'tt0061418', 'imdb_score': '7.7', 'imdb_votes': '111189.0', 'tmdb_popularity': '15.309', 'tmdb_score': '7.5', 'genres_array': ['drama', 'crime', 'action'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8910'), 'id': 'tm67378', 'title': 'The Professionals', 'type': 'MOVIE', 'description': 'An arrogant Texas millionaire hires four adventurers to rescue his kidnapped wife from a notorious Mexican bandit.', 'release_year': '1966', 'age_certification': 'PG-13', 'runtime': '117', 'genres': "['western', 'action', 'european']", 'production_countries': "['US']", 'imdb_id': 'tt0060862', 'imdb_score': '7.3', 'imdb_votes': '16168.0', 'tmdb_popularity': '12.155', 'tmdb_score': '7.1', 'genres_array': ['western', 'action', 'european'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8911'), 'id': 'tm44204', 'title': 'The Guns of Navarone', 'type': 'MOVIE', 'description': 'A team of allied saboteurs are assigned an impossible mission: infiltrate an impregnable Nazi-held island and destroy the two enormous long-range field guns that prevent the rescue of 2,000 trapped British soldiers.', 'release_year': '1961', 'runtime': '158', 'genres': "['war', 'action', 'drama']", 'production_countries': "['US', 'GB']", 'imdb_id': 'tt0054953', 'imdb_score': '7.5', 'imdb_votes': '50150.0', 'tmdb_popularity': '15.405', 'tmdb_score': '7.4', 'genres_array': ['war', 'action', 'drama'], 'production_countries_array': ['US', 'GB']}
# {'_id': ObjectId('6311590052336cecf29f8912'), 'id': 'tm69778', 'title': 'Lupin the Third: The Castle of Cagliostro', 'type': 'MOVIE', 'description': "After a successful robbery leaves famed thief Lupin the Third and his partner Jigen with nothing but a large amount of expertly crafted counterfeit bills, he decides to track down the forgers responsible—and steal any other treasures he may find in the Castle of Cagliostro, including the 'damsel in distress' he finds imprisoned there.", 'release_year': '1979', 'age_certification': 'PG', 'runtime': '100', 'genres': "['comedy', 'animation', 'action', 'fantasy', 'family']", 'production_countries': "['JP']", 'imdb_id': 'tt0079833', 'imdb_score': '7.6', 'imdb_votes': '30277.0', 'tmdb_popularity': '14.008', 'tmdb_score': '7.5', 'genres_array': ['comedy', 'animation', 'action', 'fantasy', 'family'], 'production_countries_array': ['JP']}
# {'_id': ObjectId('6311590052336cecf29f8913'), 'id': 'tm69997', 'title': 'Richard Pryor: Live in Concert', 'type': 'MOVIE', 'description': 'Richard Pryor delivers monologues on race, sex, family and his favorite target—himself, live at the Terrace Theatre in Long Beach, California.', 'release_year': '1979', 'age_certification': 'R', 'runtime': '78', 'genres': "['comedy', 'documentation']", 'production_countries': "['US']", 'imdb_id': 'tt0079807', 'imdb_score': '8.1', 'imdb_votes': '5141.0', 'tmdb_popularity': '4.681', 'tmdb_score': '7.5', 'genres_array': ['comedy', 'documentation'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8914'), 'id': 'tm96649', 'title': 'The Long Riders', 'type': 'MOVIE', 'description': 'The origins, exploits and the ultimate fate of the James gang is told in a sympathetic portrayal of the bank robbers made up of brothers who begin their legendary bank raids because of revenge.', 'release_year': '1980', 'age_certification': 'R', 'runtime': '99', 'genres': "['western', 'crime']", 'production_countries': "['US']", 'imdb_id': 'tt0081071', 'imdb_score': '6.9', 'imdb_votes': '11329.0', 'tmdb_popularity': '8.808', 'tmdb_score': '6.6', 'genres_array': ['western', 'crime'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8915'), 'id': 'tm16479', 'title': 'White Christmas', 'type': 'MOVIE', 'description': 'Two talented song-and-dance men team up after the war to become one of the hottest acts in show business. In time they befriend and become romantically involved with the beautiful Haynes sisters who comprise a sister act.', 'release_year': '1954', 'runtime': '115', 'genres': "['romance', 'comedy', 'music']", 'production_countries': "['US']", 'imdb_id': 'tt0047673', 'imdb_score': '7.5', 'imdb_votes': '42373.0', 'tmdb_popularity': '9.71', 'tmdb_score': '7.2', 'genres_array': ['romance', 'comedy', 'music'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8916'), 'id': 'tm135083', 'title': 'Cairo Station', 'type': 'MOVIE', 'description': "Qinawi, a physically challenged peddler who makes his living selling newspapers in the central Cairo train station, is obsessed by Hanuma, an attractive young woman who sells drinks. While she jokes with him about a possible relationship, she is actually in love with Abu Siri, a strong and respected porter at the station who is struggling to unionize his fellow workers to combat their boss' exploitative and abusive treatment.", 'release_year': '1958', 'runtime': '77', 'genres': "['drama', 'crime', 'comedy']", 'production_countries': "['EG']", 'imdb_id': 'tt0051390', 'imdb_score': '7.5', 'imdb_votes': '4385.0', 'tmdb_popularity': '3.556', 'tmdb_score': '7.4', 'genres_array': ['drama', 'crime', 'comedy'], 'production_countries_array': ['EG']}
# {'_id': ObjectId('6311590052336cecf29f8917'), 'id': 'tm14491', 'title': 'The Queen', 'type': 'MOVIE', 'description': 'In 1967, New York City is host to the Miss All-American Camp Beauty Pageant. This documentary takes a look behind the scenes, transporting the viewer into rehearsals and dressing rooms as the drag queen subculture prepares for this big national beauty contest. Jack/Sabrina is the mistress of ceremonies, and their protégé, Miss Harlow, is in the competition. But, as the pageant approaches, the glamorous contestants veer from camaraderie to tension.', 'release_year': '1968', 'runtime': '68', 'genres': "['documentation']", 'production_countries': "['US']", 'imdb_id': 'tt0183686', 'imdb_score': '7.2', 'imdb_votes': '1117.0', 'tmdb_popularity': '2.419', 'tmdb_score': '6.5', 'genres_array': ['documentation'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8918'), 'id': 'tm89386', 'title': 'Hitler: A Career', 'type': 'MOVIE', 'description': 'A keen chronicle of the unlikely rise to power of Adolf Hitler (1889-1945) and a dissection of the Third Reich (1933-1945), but also an analysis of mass psychology and how the desperate crowd can be deceived and shepherded to the slaughterhouse.', 'release_year': '1977', 'age_certification': 'PG', 'runtime': '150', 'genres': "['documentation', 'history', 'european']", 'production_countries': "['DE']", 'imdb_id': 'tt0191182', 'imdb_score': '7.5', 'imdb_votes': '2416.0', 'tmdb_popularity': '9.305', 'tmdb_score': '7.4', 'genres_array': ['documentation', 'history', 'european'], 'production_countries_array': ['DE']}
# {'_id': ObjectId('6311590052336cecf29f8919'), 'id': 'tm156453', 'title': 'FTA', 'type': 'MOVIE', 'description': 'A documentary about a political troupe headed by actors Jane Fonda and Donald Sutherland which traveled to towns near military bases in the US in the early 1970s. The group put on shows called "F.T.A.", which stood for "F**k the Army", and was aimed at convincing soldiers to voice their opposition to the Vietnam War, which was raging at the time. Various singers, actors and other entertainers performed antiwar songs and skits during the show.', 'release_year': '1972', 'age_certification': 'R', 'runtime': '97', 'genres': "['comedy', 'documentation', 'music']", 'production_countries': "['US']", 'imdb_id': 'tt0068562', 'imdb_score': '6.2', 'imdb_votes': '411.0', 'tmdb_popularity': '2.466', 'tmdb_score': '6.1', 'genres_array': ['comedy', 'documentation', 'music'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f891a'), 'id': 'tm27298', 'title': 'Saladin the Victorious', 'type': 'MOVIE', 'description': 'Saladin, the first sultan of Egypt and Syria, leads the Muslim military campaign against the invading Christians from Europe during the Third Crusade.', 'release_year': '1963', 'runtime': '186', 'genres': "['drama', 'war', 'action', 'history', 'romance']", 'production_countries': "['EG']", 'imdb_id': 'tt0057357', 'imdb_score': '7.6', 'imdb_votes': '2470.0', 'tmdb_popularity': '4.816', 'tmdb_score': '7.1', 'genres_array': ['drama', 'war', 'action', 'history', 'romance'], 'production_countries_array': ['EG']}
# {'_id': ObjectId('6311590052336cecf29f891b'), 'id': 'tm356209', 'title': 'Singapore', 'type': 'MOVIE', 'description': 'When his employee disappears in Singapore, Shyam travels from India to investigate the absence and becomes entangled in a deadly plot.', 'release_year': '1960', 'runtime': '158', 'genres': "['drama', 'thriller', 'crime']", 'production_countries': "['IN']", 'imdb_id': 'tt0268639', 'imdb_score': '6.4', 'imdb_votes': '82.0', 'tmdb_popularity': '1.611', 'tmdb_score': '6.3', 'genres_array': ['drama', 'thriller', 'crime'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f891c'), 'id': 'tm204541', 'title': 'Dark Waters', 'type': 'MOVIE', 'description': "Ragab, a poor sailor, returns home to Alexandria after three years of absence, during which he tried to save money to marry his one true love, Hamedah. But there's trouble on the harbor, and with an old friend.", 'release_year': '1956', 'runtime': '120', 'genres': "['drama', 'action', 'romance', 'thriller']", 'production_countries': "['EG']", 'imdb_id': 'tt0049761', 'imdb_score': '6.7', 'imdb_votes': '590.0', 'tmdb_popularity': '1.044', 'tmdb_score': '5.9', 'genres_array': ['drama', 'action', 'romance', 'thriller'], 'production_countries_array': ['EG']}
# {'_id': ObjectId('6311590052336cecf29f891d'), 'id': 'tm14350', 'title': 'Alexandria… Why?', 'type': 'MOVIE', 'description': 'Set against the panoramic backdrop of war-torn Egypt, director Youssef Chahine tells a highly personal tale of love and determination. Amid the poverty, death and suffering caused by World War II, 18 year-old Yehia, retreats into a private world of fantasy and longing. Obsessed with Hollywood, he dreams of one day studying filmmaking in America, but after falling in love and discovering the lies of European occupation, Yehia profoundly reevaluates his identity and allegiances.', 'release_year': '1979', 'runtime': '133', 'genres': "['drama']", 'production_countries': "['EG']", 'imdb_id': 'tt0077751', 'imdb_score': '7.2', 'imdb_votes': '1689.0', 'tmdb_popularity': '1.736', 'tmdb_score': '6.0', 'genres_array': ['drama'], 'production_countries_array': ['EG']}
# {'_id': ObjectId('6311590052336cecf29f891e'), 'id': 'tm102287', 'title': 'Raya and Sakina', 'type': 'MOVIE', 'description': "Dramatic rendition of a real life crime wave that terrorized the city of Alexandria, Egypt, between the years 1920 and 1922. Women are disappearing without a trace in what looked like the work of a serial killer. Being Egypt's first ever case of serial killings, the police is relentless and assigns the case to their best inspector. He traces the leads to sisters Raya and Sekina, but it becomes a race against time before they kill again.", 'release_year': '1953', 'runtime': '105', 'genres': "['drama', 'thriller', 'crime', 'history']", 'production_countries': "['EG']", 'imdb_id': 'tt0316472', 'imdb_score': '6.8', 'imdb_votes': '231.0', 'tmdb_popularity': '1.826', 'tmdb_score': '5.8', 'genres_array': ['drama', 'thriller', 'crime', 'history'], 'production_countries_array': ['EG']}
# {'_id': ObjectId('6311590052336cecf29f891f'), 'id': 'tm76557', 'title': 'No Longer Kids', 'type': 'MOVIE', 'description': 'By coincidence, Ahmad discovers that his father, Ramada Al Sokkary has a love letter in his suit case, which reveals his love to a woman other than his mother. Ahmad tries with his brothers and sister to find out the reasons that made their father look for another woman. The play shows the amusing acts the children undertake to save their family.', 'release_year': '1979', 'runtime': '235', 'genres': "['comedy', 'drama']", 'production_countries': "['EG']", 'imdb_id': 'tt8312792', 'imdb_score': '9.0', 'imdb_votes': '943.0', 'tmdb_popularity': '2.733', 'tmdb_score': '7.7', 'genres_array': ['comedy', 'drama'], 'production_countries_array': ['EG']}
# {'_id': ObjectId('6311590052336cecf29f8920'), 'id': 'tm71909', 'title': 'Amrapali', 'type': 'MOVIE', 'description': "After a failed conquest, Emperor Ajaatshatru pretends to be a soldier in the enemy's army to weaken them from the inside. However, he falls in love with Amrapali by faking his identity.", 'release_year': '1966', 'runtime': '120', 'genres': "['fantasy']", 'production_countries': "['IN']", 'imdb_id': 'tt0060104', 'imdb_score': '6.7', 'imdb_votes': '225.0', 'tmdb_popularity': '2.047', 'tmdb_score': '6.3', 'genres_array': ['fantasy'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f8921'), 'id': 'tm94651', 'title': 'Dostana', 'type': 'MOVIE', 'description': "Vijay and Ravi are best friends (hence the name 'Dostana') who do not even question each other about their careers. Vijay, a police officer and Ravi, a lawyer, while the former catches the criminals who smuggle, Ravi on the other hand bail those criminals, employed by Daaga. One day, both Vijay and Ravi meet Sheetal at different places and times, and both fancy the same girl, Sheetal, but Vijay's love was more serious. Ravi admits his love for Sheetal to Vijay and is devastated but Vijay decides to sacrifice his love and give Sheetal's hand. However, there was a misunderstanding when Daaga decided to stir up Vijay and Ravi's friendship by showing a photo of Vijay and Sheetal to Ravi. They became rivals for the first time and Ravi started to turn to be an enemy of Vijay. Do their friendship recover? Does Ravi get to know the truth? Do Sheetal get back with Vijay?", 'release_year': '1980', 'runtime': '161', 'genres': "['drama', 'comedy', 'romance', 'action', 'crime']", 'production_countries': "['IN']", 'imdb_id': 'tt0080653', 'imdb_score': '2.1', 'imdb_votes': '25.0', 'tmdb_popularity': '3.46', 'tmdb_score': '4.9', 'genres_array': ['drama', 'comedy', 'romance', 'action', 'crime'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f8922'), 'id': 'tm19608', 'title': 'The Blazing Sun', 'type': 'MOVIE', 'description': "A rich landlord floods and destroys a village on purpose to prevent the people living there from making a profit off their crops. What he doesn't know is that his own daughter is in love with Ahmed, a young man from the village.", 'release_year': '1954', 'runtime': '100', 'genres': "['romance', 'crime', 'drama']", 'production_countries': "['EG']", 'imdb_id': 'tt0044429', 'imdb_score': '7.4', 'imdb_votes': '1219.0', 'tmdb_popularity': '1.866', 'tmdb_score': '7.0', 'genres_array': ['romance', 'crime', 'drama'], 'production_countries_array': ['EG']}
# {'_id': ObjectId('6311590052336cecf29f8923'), 'id': 'ts45948', 'title': "Monty Python's Fliegender Zirkus", 'type': 'SHOW', 'description': "Monty Python's Fliegender Zirkus consisted of two 45-minute Monty Python German television comedy specials produced by WDR for West German television. The two episodes were first broadcast in January and December 1972 and were shot entirely on film and mostly on location in Bavaria, with the first episode recorded in German and the second recorded in English and then dubbed into German.", 'release_year': '1972', 'age_certification': 'TV-MA', 'runtime': '43', 'genres': "['comedy']", 'production_countries': '[]', 'seasons': '1.0', 'imdb_id': 'tt0202477', 'imdb_score': '8.1', 'imdb_votes': '2144.0', 'tmdb_popularity': '1.49', 'tmdb_score': '7.0', 'genres_array': ['comedy'], 'production_countries_array': ['']}
# {'_id': ObjectId('6311590052336cecf29f8924'), 'id': 'tm90896', 'title': 'The Return of the Prodigal Son', 'type': 'MOVIE', 'description': 'In this Andre Gide adaptation, an activist is released after many years in prison and returns home, shaking up established relationships among his family members at the farm governed by his strict father. Demonstrating Chahine’s eclecticism, this is an elegant melodrama, exuberant musical, layered allegory, and profound portrait of personal and political disillusionment.', 'release_year': '1976', 'runtime': '124', 'genres': "['drama', 'crime']", 'production_countries': "['DZ', 'EG']", 'imdb_id': 'tt0074168', 'imdb_score': '7.2', 'imdb_votes': '768.0', 'tmdb_popularity': '3.768', 'tmdb_score': '5.4', 'genres_array': ['drama', 'crime'], 'production_countries_array': ['DZ', 'EG']}
# {'_id': ObjectId('6311590052336cecf29f8925'), 'id': 'tm75975', 'title': 'Prince', 'type': 'MOVIE', 'description': "To better himself, a spoiled prince temporarily assumes a commoner's identity. But he soon learns his palace has been gifted to his father's new wife.", 'release_year': '1969', 'runtime': '152', 'genres': "['romance']", 'production_countries': "['IN']", 'imdb_id': 'tt0064842', 'imdb_score': '6.9', 'imdb_votes': '168.0', 'tmdb_popularity': '1.788', 'tmdb_score': '7.0', 'genres_array': ['romance'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f8926'), 'id': 'tm97793', 'title': 'Lock Your Girls In', 'type': 'MOVIE', 'description': 'Dr. Raafat faces challenges and difficulties in raising his three daughters, Fawzia (Sanaa Younis), Soso (Shreihan) and Nadia (Ijlal Zaki).', 'release_year': '1980', 'runtime': '230', 'genres': "['comedy']", 'production_countries': "['EG']", 'tmdb_popularity': '2.313', 'tmdb_score': '8.0', 'genres_array': ['comedy'], 'production_countries_array': ['EG']}
# {'_id': ObjectId('6311590052336cecf29f8927'), 'id': 'tm85426', 'title': "The Witness Who Didn't See Anything", 'type': 'MOVIE', 'description': 'An Egyptian comedy play about an innocent, clueless and naive young man who is asked to stand as a witness on a murder trial of a belly dancer who lived downstairs from his apartment.', 'release_year': '1976', 'runtime': '217', 'genres': "['comedy']", 'production_countries': "['EG']", 'tmdb_popularity': '2.612', 'tmdb_score': '7.7', 'genres_array': ['comedy'], 'production_countries_array': ['EG']}
# {'_id': ObjectId('6311590052336cecf29f8928'), 'id': 'tm188894', 'title': 'The School of Mischief', 'type': 'MOVIE', 'description': 'This play is about a female teacher and how she transformed 5 rebellious students into model students.', 'release_year': '1973', 'runtime': '251', 'genres': "['comedy']", 'production_countries': "['EG']", 'tmdb_popularity': '3.381', 'tmdb_score': '8.5', 'genres_array': ['comedy'], 'production_countries_array': ['EG']}
# {'_id': ObjectId('6311590052336cecf29f8929'), 'id': 'tm107372', 'title': 'Manoranjan', 'type': 'MOVIE', 'description': "Havaldar Ratan is a rookie at the local police station, and is assigned duty on foot patrol on Manoranjan Street, a notorious red-light area, on the very first day of his job. He strikes up a conversation with a good-looking young woman named Nisha, and tells her that there is a possible violation of Suppression of Immoral Trafficking Act taking place on this street. He witnesses several women soliciting men, and decides to call in the paddy wagon, and get them arrested. Alas, one of the men frequenting the prostitutes is none other than Ratan's superior officer, who immediately summons Ratan, and has him removed from service on corruption charges. Nisha takes pity on a homeless and unemployed Ratan, and asks him to live with her. He does not want her to sell her body, and so he decides to work at night, and during the day he takes on the guise of a rich Nawab and spends time with her.", 'release_year': '1974', 'runtime': '162', 'genres': "['comedy', 'drama', 'romance']", 'production_countries': "['IN']", 'imdb_id': 'tt0071811', 'imdb_score': '6.5', 'imdb_votes': '236.0', 'tmdb_popularity': '1.22', 'tmdb_score': '5.3', 'genres_array': ['comedy', 'drama', 'romance'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f892a'), 'id': 'tm200475', 'title': 'Beirut, Oh Beirut', 'type': 'MOVIE', 'description': 'In the aftermath of the 1967 defeat, four young Lebanese try to figure out their places in a society whose rules seem to have changed. It proved to be an extraordinary anticipation of the civil war that would engulf the country while the film was being edited.', 'release_year': '1975', 'runtime': '110', 'genres': "['drama']", 'production_countries': "['LB']", 'imdb_id': 'tt0169599', 'imdb_score': '6.5', 'imdb_votes': '106.0', 'tmdb_popularity': '1.104', 'tmdb_score': '7.3', 'genres_array': ['drama'], 'production_countries_array': ['LB']}
# {'_id': ObjectId('6311590052336cecf29f892b'), 'id': 'tm259855', 'title': 'We Are All for the Fatherland', 'type': 'MOVIE', 'description': 'After the 1978 Israeli invasion of Lebanon, children try to sing the national anthem as citizens search for hope in the war-torn South.', 'release_year': '1979', 'runtime': '74', 'genres': "['documentation']", 'production_countries': "['FR', 'LB', 'CA']", 'imdb_id': 'tt0170799', 'imdb_score': '6.2', 'imdb_votes': '43.0', 'tmdb_popularity': '0.6', 'tmdb_score': '5.3', 'genres_array': ['documentation'], 'production_countries_array': ['FR', 'LB', 'CA']}
# {'_id': ObjectId('6311590052336cecf29f892c'), 'id': 'tm259684', 'title': 'Whispers', 'type': 'MOVIE', 'description': "At every station, between sites filled with poetry and nostalgia for a bygone era, the poet's dashed dreams and idealized vision of her country coincide with the director's own.", 'release_year': '1980', 'runtime': '93', 'genres': "['documentation']", 'production_countries': "['FR', 'LB', 'CA']", 'imdb_id': 'tt0170803', 'imdb_score': '7.8', 'imdb_votes': '75.0', 'tmdb_popularity': '1.4', 'tmdb_score': '5.0', 'genres_array': ['documentation'], 'production_countries_array': ['FR', 'LB', 'CA']}
# {'_id': ObjectId('6311590052336cecf29f892d'), 'id': 'tm344089', 'title': 'Lal Patthar', 'type': 'MOVIE', 'description': 'Raja Kumar Bahadur alias Gyan Shankar Rai has been a total abstainer all his life, never touching a drop of alcohol, and keeping away from women and all known vices all his life. Then one day he sees a young woman named Saudamani, and instantly falls in love with her. He finds out about her background, and virtually buys her, and brings her to his palatial home. This is when he takes to drinking, and wooing her, and renaming her Madhuri, but refrains from marrying her. Years later, he sees another beautiful woman, about half his age, named Sumita, meets with her parents, pays off their debts, and marries her in the bargain.', 'release_year': '1971', 'runtime': '153', 'genres': "['drama']", 'production_countries': "['IN']", 'imdb_id': 'tt0237395', 'imdb_score': '6.2', 'imdb_votes': '137.0', 'tmdb_popularity': '0.732', 'tmdb_score': '7.0', 'genres_array': ['drama'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f892e'), 'id': 'tm358653', 'title': 'Ujala', 'type': 'MOVIE', 'description': 'An honest man dreams of a better life for his family, but a childhood friend leads him into a world of crime that keeps happiness just out of reach.', 'release_year': '1959', 'runtime': '142', 'genres': "['romance', 'crime', 'drama']", 'production_countries': "['IN']", 'imdb_id': 'tt0157132', 'imdb_score': '6.7', 'imdb_votes': '78.0', 'tmdb_popularity': '0.998', 'tmdb_score': '6.0', 'genres_array': ['romance', 'crime', 'drama'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f892f'), 'id': 'tm100027', 'title': 'Alibaba Aur 40 Chor', 'type': 'MOVIE', 'description': 'The movie is based on the story of Ali Baba and the Forty Thieves, from the One Thousand and One Nights or Arabian Tales. The role of Ali Baba is played by Dharmendra and Hema Malini play Morjina.', 'release_year': '1979', 'runtime': '138', 'genres': "['drama', 'action', 'romance', 'family', 'fantasy']", 'production_countries': "['IN', 'SU']", 'imdb_id': 'tt0079749', 'imdb_score': '6.2', 'imdb_votes': '555.0', 'tmdb_popularity': '2.554', 'tmdb_score': '6.8', 'genres_array': ['drama', 'action', 'romance', 'family', 'fantasy'], 'production_countries_array': ['IN', 'SU']}
# {'_id': ObjectId('6311590052336cecf29f8930'), 'id': 'tm10204', 'title': 'Professor', 'type': 'MOVIE', 'description': 'Sita devi is a very strict aunt for a number of young ladies, and does not allow them to fraternize with males. Along comes Pritam disguised as an elderly Professor Khanna to break every possible rule of the aunt', 'release_year': '1962', 'runtime': '163', 'genres': "['romance', 'comedy', 'drama']", 'production_countries': "['IN']", 'imdb_id': 'tt0056379', 'imdb_score': '6.8', 'imdb_votes': '285.0', 'tmdb_popularity': '1.9', 'tmdb_score': '5.8', 'genres_array': ['romance', 'comedy', 'drama'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f8931'), 'id': 'tm403346', 'title': 'Chadi Jawani Budhe Nu', 'type': 'MOVIE', 'description': 'A small-time businessman (B.S. Sood) reaches the "naughty forties". Now his wife is not good enough anymore, so he decides he needs a modern up to date mistress, resulting in hilarious situations.', 'release_year': '1976', 'runtime': '135', 'genres': "['romance']", 'production_countries': "['IN']", 'imdb_id': 'tt3290368', 'imdb_score': '4.6', 'imdb_votes': '14.0', 'tmdb_popularity': '1.24', 'tmdb_score': '6.0', 'genres_array': ['romance'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f8932'), 'id': 'tm16812', 'title': 'Bandie', 'type': 'MOVIE', 'description': "Maharaj Brajbhan lives a wealthy lifestyle in Bharatpur, India along with his wife, Badi Rani, but have been unable to conceive for Bharatpur, and have no choice but to leave it's reigns with Brajban's widowed cousin, Vikram, and his son, Kanchan. When Vikram finds out that Badi Rani is pregnant, he plots to first sully her character by having her abducted, then shunned by the Maharaj, and then decides to have her killed. But her killer has a change of heart and lets her live. She gives birth to a son, names him Bhola, and starts living a simple lifestyle in a Mandir with the help of it's Poojary. Years later Vikram finds out she is alive and kills her, as well the Poojary and the Poojary's son. Bhola witnesses this, manages to escape, starts to live with a poor widow, grows up uneducated, and makes a living through crime.", 'release_year': '1978', 'runtime': '141', 'genres': "['drama', 'romance', 'action']", 'production_countries': "['IN']", 'imdb_id': 'tt1219315', 'imdb_score': '4.2', 'imdb_votes': '35.0', 'tmdb_popularity': '1.097', 'tmdb_score': '6.0', 'genres_array': ['drama', 'romance', 'action'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f8933'), 'id': 'tm336403', 'title': 'Khoon Khoon', 'type': 'MOVIE', 'description': 'As a crazed killer blazes a trail of blood through an anxious city, a hardened cop aims to take him down by any means in this remake of Dirty Harry.', 'release_year': '1973', 'runtime': '131', 'genres': "['drama', 'crime', 'thriller']", 'production_countries': "['IN']", 'imdb_id': 'tt0230412', 'imdb_score': '5.1', 'imdb_votes': '41.0', 'tmdb_popularity': '1.08', 'tmdb_score': '3.8', 'genres_array': ['drama', 'crime', 'thriller'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f8934'), 'id': 'tm119776', 'title': 'Top Gun', 'type': 'MOVIE', 'description': 'A heart-pounding combination of action, music and incredible aerial photography helped make Top Gun the blockbuster hit. of 1986. Top Gun takes a look at the danger and excitement that awaits every pilot at the Navy\'s prestigious fighter weapons school. Tom Cruise is superb as Lt. Pete "Maverick" Mitchell, a daring young flyer who\'s out to become the best. And Kelly McGillis sizzles as the civilian instructor who teaches Maverick a few things you can\'t learn in a classroom.', 'release_year': '1986', 'age_certification': 'PG', 'runtime': '110', 'genres': "['drama', 'action']", 'production_countries': "['US']", 'imdb_id': 'tt0092099', 'imdb_score': '6.9', 'imdb_votes': '329656.0', 'tmdb_popularity': '112.137', 'tmdb_score': '7.0', 'genres_array': ['drama', 'action'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8935'), 'id': 'ts20681', 'title': 'Seinfeld', 'type': 'SHOW', 'description': "A stand-up comedian and his three offbeat friends weather the pitfalls and payoffs of life in New York City in the '90s. It's a show about nothing.", 'release_year': '1989', 'age_certification': 'TV-PG', 'runtime': '24', 'genres': "['comedy']", 'production_countries': "['US']", 'seasons': '9.0', 'imdb_id': 'tt0098904', 'imdb_score': '8.9', 'imdb_votes': '302700.0', 'tmdb_popularity': '128.743', 'tmdb_score': '8.3', 'genres_array': ['comedy'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8936'), 'id': 'tm111075', 'title': 'Stand by Me', 'type': 'MOVIE', 'description': 'Gordie, Chris, Teddy and Vern are four friends who decide to hike to find the corpse of Ray Brower, a local teenager, who was hit by a train while plucking blueberries in the wild.', 'release_year': '1986', 'age_certification': 'R', 'runtime': '89', 'genres': "['drama']", 'production_countries': "['US']", 'imdb_id': 'tt0092005', 'imdb_score': '8.1', 'imdb_votes': '392790.0', 'tmdb_popularity': '16.096', 'tmdb_score': '7.9', 'genres_array': ['drama'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8937'), 'id': 'tm180542', 'title': 'Once Upon a Time in America', 'type': 'MOVIE', 'description': 'A former Prohibition-era Jewish gangster returns to the Lower East Side of Manhattan over thirty years later, where he once again must confront the ghosts and regrets of his old life.', 'release_year': '1984', 'age_certification': 'R', 'runtime': '229', 'genres': "['drama', 'crime', 'european']", 'production_countries': "['US', 'IT']", 'imdb_id': 'tt0087843', 'imdb_score': '8.3', 'imdb_votes': '342335.0', 'tmdb_popularity': '21.322', 'tmdb_score': '8.4', 'genres_array': ['drama', 'crime', 'european'], 'production_countries_array': ['US', 'IT']}
# {'_id': ObjectId('6311590052336cecf29f8938'), 'id': 'tm138875', 'title': 'When Harry Met Sally...', 'type': 'MOVIE', 'description': "During their travel from Chicago to New York, Harry and Sally debate whether or not sex ruins a friendship between a man and a woman. Eleven years later, and they're still no closer to finding the answer.", 'release_year': '1989', 'age_certification': 'R', 'runtime': '96', 'genres': "['romance', 'comedy', 'drama']", 'production_countries': "['US']", 'imdb_id': 'tt0098635', 'imdb_score': '7.7', 'imdb_votes': '212913.0', 'tmdb_popularity': '16.005', 'tmdb_score': '7.4', 'genres_array': ['romance', 'comedy', 'drama'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8939'), 'id': 'tm155792', 'title': 'Teenage Mutant Ninja Turtles', 'type': 'MOVIE', 'description': 'A quartet of humanoid turtles, trained by their mentor in ninjitsu, must learn to work together to face the menace of Shredder and the Foot Clan.', 'release_year': '1990', 'age_certification': 'PG', 'runtime': '93', 'genres': "['scifi', 'action', 'comedy', 'family']", 'production_countries': "['HK', 'US']", 'imdb_id': 'tt0100758', 'imdb_score': '6.7', 'imdb_votes': '92647.0', 'tmdb_popularity': '22.75', 'tmdb_score': '6.6', 'genres_array': ['scifi', 'action', 'comedy', 'family'], 'production_countries_array': ['HK', 'US']}
# {'_id': ObjectId('6311590052336cecf29f893a'), 'id': 'tm22327', 'title': 'Full Metal Jacket', 'type': 'MOVIE', 'description': 'A pragmatic U.S. Marine observes the dehumanizing effects the U.S.-Vietnam War has on his fellow recruits from their brutal boot camp training to the bloody street fighting in Hue.', 'release_year': '1987', 'age_certification': 'R', 'runtime': '116', 'genres': "['drama', 'war']", 'production_countries': "['GB', 'US']", 'imdb_id': 'tt0093058', 'imdb_score': '8.3', 'imdb_votes': '723306.0', 'tmdb_popularity': '36.502', 'tmdb_score': '8.1', 'genres_array': ['drama', 'war'], 'production_countries_array': ['GB', 'US']}
# {'_id': ObjectId('6311590052336cecf29f893b'), 'id': 'tm54450', 'title': 'Christine', 'type': 'MOVIE', 'description': "Geeky student Arnie Cunningham falls for Christine, a rusty 1958 Plymouth Fury, and becomes obsessed with restoring the classic automobile to her former glory. As the car changes, so does Arnie, whose newfound confidence turns to arrogance behind the wheel of his exotic beauty. Arnie's girlfriend Leigh and best friend Dennis reach out to him, only to be met by a Fury like no other.", 'release_year': '1983', 'age_certification': 'R', 'runtime': '90', 'genres': "['horror', 'thriller', 'european']", 'production_countries': "['US']", 'imdb_id': 'tt0085333', 'imdb_score': '6.7', 'imdb_votes': '80945.0', 'tmdb_popularity': '19.311', 'tmdb_score': '6.8', 'genres_array': ['horror', 'thriller', 'european'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f893c'), 'id': 'tm2386', 'title': 'A Nightmare on Elm Street', 'type': 'MOVIE', 'description': "Teenagers in a small town are dropping like flies, apparently in the grip of mass hysteria causing their suicides. A cop's daughter, Nancy Thompson, traces the cause to child molester Fred Krueger, who was burned alive by angry parents many years before. Krueger has now come back in the dreams of his killers' children, claiming their lives as his revenge. Nancy and her boyfriend, Glen, must devise a plan to lure the monster out of the realm of nightmares and into the real world...", 'release_year': '1984', 'age_certification': 'R', 'runtime': '91', 'genres': "['horror']", 'production_countries': "['US']", 'imdb_id': 'tt0087800', 'imdb_score': '7.4', 'imdb_votes': '230543.0', 'tmdb_popularity': '53.853', 'tmdb_score': '7.3', 'genres_array': ['horror'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f893d'), 'id': 'ts22082', 'title': 'Knight Rider', 'type': 'SHOW', 'description': "Michael Long, an undercover police officer, is shot while investigating a case and left for dead by his assailants. He is rescued by Wilton Knight, a wealthy, dying millionaire and inventor who arranges life-saving surgery, including a new face and a new identity--that of Michael Knight. Michael is then given a special computerized and indestructible car called the Knight Industries Two Thousand (nicknamed KITT), and a mission: apprehend criminals who are beyond the reach of the law. The series depicts Michael's exploits as he and KITT battle the forces of evil on behalf of the Foundation for Law and Government.", 'release_year': '1982', 'age_certification': 'TV-PG', 'runtime': '51', 'genres': "['action', 'scifi', 'crime', 'drama']", 'production_countries': "['US']", 'seasons': '4.0', 'imdb_id': 'tt0083437', 'imdb_score': '6.9', 'imdb_votes': '33760.0', 'tmdb_popularity': '44.378', 'tmdb_score': '7.5', 'genres_array': ['action', 'scifi', 'crime', 'drama'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f893e'), 'id': 'tm145608', 'title': 'Awakenings', 'type': 'MOVIE', 'description': 'Dr. Malcolm Sayer, a shy research physician, uses an experimental drug to "awaken" the catatonic victims of a rare disease. Leonard is the first patient to receive the controversial treatment. His awakening, filled with awe and enthusiasm, proves a rebirth for Sayer too, as the exuberant patient reveals life\'s simple but unutterably sweet pleasures to the introverted doctor.', 'release_year': '1990', 'age_certification': 'PG-13', 'runtime': '120', 'genres': "['drama', 'european']", 'production_countries': "['US']", 'imdb_id': 'tt0099077', 'imdb_score': '7.8', 'imdb_votes': '137549.0', 'tmdb_popularity': '13.761', 'tmdb_score': '7.8', 'genres_array': ['drama', 'european'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f893f'), 'id': 'ts21715', 'title': 'Thomas & Friends', 'type': 'SHOW', 'description': "Thomas & Friends is a British children's television series, which had its first broadcast on the ITV network on 4 September 1984. It is based on The Railway Series of books by the Reverend Wilbert Awdry and his son, Christopher Awdry. These books deal with the adventures of a group of anthropomorphised locomotives and road vehicles who live on the fictional Island of Sodor. The books were based on stories Wilbert told to entertain his son, Christopher during his recovery from measles. From Series one to four, many of the stories are based on events from Awdry's personal experience.", 'release_year': '1984', 'age_certification': 'TV-Y', 'runtime': '10', 'genres': "['family', 'comedy', 'music', 'action', 'animation', 'fantasy', 'drama']", 'production_countries': "['GB']", 'seasons': '24.0', 'imdb_id': 'tt0086815', 'imdb_score': '6.5', 'imdb_votes': '4948.0', 'tmdb_popularity': '49.384', 'tmdb_score': '6.6', 'genres_array': ['family', 'comedy', 'music', 'action', 'animation', 'fantasy', 'drama'], 'production_countries_array': ['GB']}
# {'_id': ObjectId('6311590052336cecf29f8940'), 'id': 'tm41289', 'title': 'Annie', 'type': 'MOVIE', 'description': 'An orphan in a facility run by the mean Miss Hannigan, Annie believes that her parents left her there by mistake. When a rich man named Oliver "Daddy" Warbucks decides to let an orphan live at his home to promote his image, Annie is selected. While Annie gets accustomed to living in Warbucks\' mansion, she still longs to meet her parents. So Warbucks announces a search for them and a reward, which brings out many frauds.', 'release_year': '1982', 'age_certification': 'PG', 'runtime': '127', 'genres': "['drama', 'family', 'comedy']", 'production_countries': "['US']", 'imdb_id': 'tt0083564', 'imdb_score': '6.6', 'imdb_votes': '44866.0', 'tmdb_popularity': '15.857', 'tmdb_score': '6.5', 'genres_array': ['drama', 'family', 'comedy'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8941'), 'id': 'tm132694', 'title': 'Pet Sematary', 'type': 'MOVIE', 'description': 'Dr. Louis Creed\'s family moves into the country house of their dreams and discover a pet cemetery at the back of their property. The cursed burial ground deep in the woods brings the dead back to life -- with "minor" problems. At first, only the family\'s cat makes the return trip, but an accident forces a heartbroken father to contemplate the unthinkable.', 'release_year': '1989', 'age_certification': 'R', 'runtime': '103', 'genres': "['horror', 'fantasy', 'thriller']", 'production_countries': "['US']", 'imdb_id': 'tt0098084', 'imdb_score': '6.5', 'imdb_votes': '102212.0', 'tmdb_popularity': '32.854', 'tmdb_score': '6.6', 'genres_array': ['horror', 'fantasy', 'thriller'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8942'), 'id': 'ts20678', 'title': 'Saved by the Bell', 'type': 'SHOW', 'description': "Lovable schemer Zack Morris leads his pals on adventures at California's Bayside High School. The friends navigate relationships, final exams, school dances, breakups and more while frequently frustrating their principal, Mr. Richard Belding, who does his best to keep them in check.", 'release_year': '1989', 'age_certification': 'TV-G', 'runtime': '23', 'genres': "['comedy', 'romance', 'family']", 'production_countries': "['US']", 'seasons': '5.0', 'imdb_id': 'tt0096694', 'imdb_score': '7.1', 'imdb_votes': '34854.0', 'tmdb_popularity': '16.945', 'tmdb_score': '8.0', 'genres_array': ['comedy', 'romance', 'family'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f8943'), 'id': 'tm117580', 'title': "She's Gotta Have It", 'type': 'MOVIE', 'description': 'The story of Nola Darling\'s simultaneous sexual relationships with three different men is told by her and by her partners and other friends. All three men wanted her to commit solely to them; Nola resists being "owned" by a single partner.', 'release_year': '1986', 'age_certification': 'R', 'runtime': '84', 'genres': "['comedy', 'romance']", 'production_countries': "['US']", 'imdb_id': 'tt0091939', 'imdb_score': '6.7', 'imdb_votes': '14277.0', 'tmdb_popularity': '6.212', 'tmdb_score': '6.7', 'genres_array': ['comedy', 'romance'], 'production_countries_array': ['US']}
# ...
# {'_id': ObjectId('6311590052336cecf29f94f6'), 'id': 'tm1063790', 'title': 'A Man for The Weekend', 'type': 'MOVIE', 'description': 'A career-focused woman convinces a colleague to pose as her boyfriend for a family visit -- and must face a meddling mom and some unexpected feelings.', 'release_year': '2017', 'runtime': '94', 'genres': "['romance', 'comedy']", 'production_countries': "['CM']", 'imdb_id': 'tt15007420', 'imdb_score': '4.0', 'imdb_votes': '11.0', 'tmdb_popularity': '1.674', 'tmdb_score': '2.0', 'genres_array': ['romance', 'comedy'], 'production_countries_array': ['CM']}
# {'_id': ObjectId('6311590052336cecf29f94f7'), 'id': 'tm358239', 'title': 'DeRay Davis: How to Act Black', 'type': 'MOVIE', 'description': 'Dynamic comic DeRay Davis hits the stage like a ball of fire, nailing the finer points of living, dating and handling show business as a black man.', 'release_year': '2017', 'age_certification': 'PG', 'runtime': '66', 'genres': "['comedy']", 'production_countries': "['US']", 'imdb_id': 'tt7288084', 'imdb_score': '6.1', 'imdb_votes': '427.0', 'tmdb_popularity': '3.191', 'tmdb_score': '6.1', 'genres_array': ['comedy'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f94f8'), 'id': 'tm354136', 'title': 'El Especial de Alex Fernández, el Especial', 'type': 'MOVIE', 'description': 'From a Mexico City theme park, energetic stand-up Alex Fernández riffs on music, cheap toys, insecurity and other fun things about growing up.', 'release_year': '2017', 'runtime': '52', 'genres': "['comedy']", 'production_countries': "['MX']", 'imdb_id': 'tt7520228', 'imdb_score': '6.6', 'imdb_votes': '73.0', 'tmdb_popularity': '0.6', 'tmdb_score': '6.7', 'genres_array': ['comedy'], 'production_countries_array': ['MX']}
# {'_id': ObjectId('6311590052336cecf29f94f9'), 'id': 'ts54112', 'title': 'Life Plan A and B', 'type': 'SHOW', 'description': "Ru Wei and You Yan have a simple relationship. But in every simple relationship, there are many difficulties. They are not rich, but they try very hard to enjoy life. They are very serious about their relationship and try their best to achieve something in life - hoping one day they can become who they want to become. One day, Ru Wei has a 'lucky chance' in life. Her company wants to send her to Shanghai, with a promotion and higher pay. These two who are deeply in love cannot bear to have a long-distance relationship. With all the uncertainties in their future, can they still stand by each other?", 'release_year': '2017', 'age_certification': 'TV-PG', 'runtime': '80', 'genres': "['drama']", 'production_countries': "['TW']", 'seasons': '1.0', 'imdb_id': 'tt7034962', 'imdb_score': '7.8', 'imdb_votes': '106.0', 'tmdb_popularity': '2.107', 'tmdb_score': '7.0', 'genres_array': ['drama'], 'production_countries_array': ['TW']}
# {'_id': ObjectId('6311590052336cecf29f94fa'), 'id': 'tm411649', 'title': 'Thug Life', 'type': 'MOVIE', 'description': 'A get-rich-quick scheme goes awry when a group of friends stumbles onto a dangerous conspiracy and wind up getting mistaken for the bad guys.', 'release_year': '2017', 'runtime': '134', 'genres': "['comedy', 'drama']", 'production_countries': "['IN']", 'imdb_id': 'tt9537072', 'imdb_score': '5.7', 'imdb_votes': '48.0', 'tmdb_popularity': '0.932', 'genres_array': ['comedy', 'drama'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f94fb'), 'id': 'tm350945', 'title': 'Posesif', 'type': 'MOVIE', 'description': 'A student diver risks her scholastic future and relationship with her father when she dates a moody transfer student consumed by their romance.', 'release_year': '2017', 'runtime': '102', 'genres': "['drama', 'comedy', 'romance']", 'production_countries': "['ID']", 'imdb_id': 'tt8425410', 'imdb_score': '7.4', 'imdb_votes': '920.0', 'tmdb_popularity': '2.403', 'tmdb_score': '7.8', 'genres_array': ['drama', 'comedy', 'romance'], 'production_countries_array': ['ID']}
# {'_id': ObjectId('6311590052336cecf29f94fc'), 'id': 'tm244310', 'title': 'Merku Thodarchi Malai', 'type': 'MOVIE', 'description': 'Living on the borders of Kerala and Tamil Nadu, Rangasamy, a laborer just like his fellow sons of soils toils, hard-working at the spice plantations owned by landlords. He lives a happy life and wishes to own a piece of land and earn a living through farming. After years of struggle, his dream finally comes true when Chaako, a local politician helps him buy the land, however, he soon faces tougher challenges as he has to deal with corrupt and wealthy politicians.', 'release_year': '2018', 'runtime': '122', 'genres': "['drama']", 'production_countries': "['IN']", 'imdb_id': 'tt7794052', 'imdb_score': '8.6', 'imdb_votes': '1810.0', 'tmdb_popularity': '2.764', 'tmdb_score': '7.4', 'genres_array': ['drama'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f94fd'), 'id': 'tm370781', 'title': 'Natalia Valdebenito: El especial', 'type': 'MOVIE', 'description': 'A Chilean comedian fuses activism with irreverence for a stand-up set filled with jokes about misogyny, reproductive rights and respecting women.', 'release_year': '2018', 'runtime': '76', 'genres': "['comedy']", 'production_countries': "['CL']", 'imdb_id': 'tt7663776', 'imdb_score': '5.1', 'imdb_votes': '82.0', 'tmdb_popularity': '1.874', 'tmdb_score': '7.3', 'genres_array': ['comedy'], 'production_countries_array': ['CL']}
# {'_id': ObjectId('6311590052336cecf29f94fe'), 'id': 'tm376709', 'title': 'Jani Dueñas: Grandes fracasos de ayer y hoy', 'type': 'MOVIE', 'description': 'Radio broadcaster, actress and comedian Jani Dueñas brings her acid sense of humor to this stand-up special as she pours out her feelings on issues that are all too universal, from aging to dieting to sex.', 'release_year': '2018', 'runtime': '77', 'genres': "['comedy']", 'production_countries': "['CL', 'MX', 'US']", 'imdb_id': 'tt7607260', 'imdb_score': '4.8', 'imdb_votes': '71.0', 'tmdb_popularity': '1.815', 'tmdb_score': '6.0', 'genres_array': ['comedy'], 'production_countries_array': ['CL', 'MX', 'US']}
# {'_id': ObjectId('6311590052336cecf29f94ff'), 'id': 'tm368284', 'title': 'Arango y Sanint: Ríase el show', 'type': 'MOVIE', 'description': 'Colombian stand-up comedians Antonio Sanint and Julián Arango impersonate an Argentine visitor and a cabbie, and a pair of dirty old men at the opera.', 'release_year': '2018', 'runtime': '62', 'genres': "['comedy']", 'production_countries': "['CO']", 'imdb_id': 'tt7606464', 'imdb_score': '4.0', 'imdb_votes': '42.0', 'tmdb_popularity': '1.4', 'tmdb_score': '4.0', 'genres_array': ['comedy'], 'production_countries_array': ['CO']}
# {'_id': ObjectId('6311590052336cecf29f9500'), 'id': 'tm328041', 'title': 'Doob', 'type': 'MOVIE', 'description': 'As a noted filmmaker’s infidelity becomes a media firestorm, his fractured family privately navigates the fallout of his actions for years to come.', 'release_year': '2017', 'runtime': '102', 'genres': "['drama']", 'production_countries': "['IN', 'BD']", 'imdb_id': 'tt5513920', 'imdb_score': '6.2', 'imdb_votes': '1863.0', 'tmdb_popularity': '2.045', 'tmdb_score': '5.7', 'genres_array': ['drama'], 'production_countries_array': ['IN', 'BD']}
# {'_id': ObjectId('6311590052336cecf29f9501'), 'id': 'tm375836', 'title': 'Adel Karam: Live from Beirut', 'type': 'MOVIE', 'description': "Which part of a sheep is tastiest? What's so funny about funerals? A Lebanese comic answers your burning questions!", 'release_year': '2018', 'age_certification': 'R', 'runtime': '59', 'genres': "['comedy']", 'production_countries': "['LB']", 'imdb_id': 'tt8081748', 'imdb_score': '5.5', 'imdb_votes': '144.0', 'tmdb_popularity': '1.76', 'tmdb_score': '7.0', 'genres_array': ['comedy'], 'production_countries_array': ['LB']}
# {'_id': ObjectId('6311590052336cecf29f9502'), 'id': 'tm404610', 'title': 'Stretch Armstrong: The Breakout', 'type': 'MOVIE', 'description': 'Villains are rampaging through Charter City and the Flex Fighters -- Jake, Ricardo and Nathan -- need your help to halt the chaos.', 'release_year': '2018', 'runtime': '45', 'genres': "['animation']", 'production_countries': "['US']", 'tmdb_popularity': '1.982', 'tmdb_score': '6.0', 'genres_array': ['animation'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f9503'), 'id': 'tm358370', 'title': 'Love and Shukla', 'type': 'MOVIE', 'description': 'A sexually inexperienced rickshaw driver struggles to build intimacy with his shy new wife in their tiny, overcrowded quarters.', 'release_year': '2017', 'runtime': '117', 'genres': "['romance', 'comedy', 'drama']", 'production_countries': "['IN']", 'imdb_id': 'tt7647198', 'imdb_score': '7.3', 'imdb_votes': '933.0', 'tmdb_popularity': '1.418', 'tmdb_score': '8.2', 'genres_array': ['romance', 'comedy', 'drama'], 'production_countries_array': ['IN']}
# {'_id': ObjectId('6311590052336cecf29f9504'), 'id': 'tm367105', 'title': 'Alejandro Riaño: Especial de stand up', 'type': 'MOVIE', 'description': 'Colombian comedian Alejandro Riaño discusses the perks of dating a she-wolf, styles of dancing, the quirks of Bogotá men and soccer game announcers.', 'release_year': '2018', 'runtime': '60', 'genres': "['comedy']", 'production_countries': "['CO']", 'imdb_id': 'tt7607558', 'imdb_score': '4.9', 'imdb_votes': '69.0', 'tmdb_popularity': '1.132', 'tmdb_score': '5.0', 'genres_array': ['comedy'], 'production_countries_array': ['CO']}
# {'_id': ObjectId('6311590052336cecf29f9505'), 'id': 'tm289882', 'title': 'Birdshot', 'type': 'MOVIE', 'description': 'A farm girl mistakenly shoots and kills an endangered Philippine Eagle. When authorities begin a manhunt to track down the eagle’s killer, they stumble upon an even more horrific discovery.', 'release_year': '2017', 'runtime': '116', 'genres': "['thriller', 'drama']", 'production_countries': "['PH']", 'imdb_id': 'tt6159150', 'imdb_score': '6.6', 'imdb_votes': '781.0', 'tmdb_popularity': '3.189', 'tmdb_score': '6.5', 'genres_array': ['thriller', 'drama'], 'production_countries_array': ['PH']}
# {'_id': ObjectId('6311590052336cecf29f9506'), 'id': 'tm370472', 'title': 'Kavin Jay : Everybody Calm Down!', 'type': 'MOVIE', 'description': 'On a mission to defy stereotypes, Malaysian stand-up comedian Kavin Jay shares stories about growing up in the VHS era with his Singapore audience.', 'release_year': '2018', 'runtime': '53', 'genres': "['comedy', 'documentation']", 'production_countries': "['XX']", 'imdb_id': 'tt7924764', 'imdb_score': '5.9', 'imdb_votes': '232.0', 'tmdb_popularity': '1.431', 'tmdb_score': '4.6', 'genres_array': ['comedy', 'documentation'], 'production_countries_array': ['XX']}
# {'_id': ObjectId('6311590052336cecf29f9507'), 'id': 'tm369453', 'title': 'Mau Nieto: viviendo sobrio… desde el bar', 'type': 'MOVIE', 'description': 'Performing at a bar, Mexican stand-up comedian Mau Nieto dishes on his modest upbringing, his failed relationships and his attempts to stay sober.', 'release_year': '2018', 'runtime': '57', 'genres': "['comedy']", 'production_countries': "['MX']", 'imdb_id': 'tt7607492', 'imdb_score': '6.7', 'imdb_votes': '80.0', 'tmdb_popularity': '1.414', 'tmdb_score': '6.2', 'genres_array': ['comedy'], 'production_countries_array': ['MX']}
# {'_id': ObjectId('6311590052336cecf29f9508'), 'id': 'tm426367', 'title': 'Coco y Raulito: Carrusel de ternura', 'type': 'MOVIE', 'description': 'A study in contrasts, comedy partners and good friends Coco Celis and Raúl Meneses alternate separate stand-up sets for double the laughs.', 'release_year': '2018', 'age_certification': 'PG-13', 'runtime': '56', 'genres': "['comedy']", 'production_countries': "['MX']", 'imdb_id': 'tt7607498', 'imdb_score': '6.6', 'imdb_votes': '39.0', 'tmdb_popularity': '1.4', 'tmdb_score': '7.0', 'genres_array': ['comedy'], 'production_countries_array': ['MX']}
# {'_id': ObjectId('6311590052336cecf29f9509'), 'id': 'tm438005', 'title': 'First Love', 'type': 'MOVIE', 'description': "In what appears to be a serendipitous encounter upon saving the life of a stranger, the calculated and reserved businessman Nick meets the impulsive and optimistic photographer Ali, who believes in destiny and carpe diem, or seizing the day. Nick, who seeks closure for his past mistakes, is drawn towards Ali's spirit and vigor. Despite living with a congenital heart disease and being on the wait-list for a heart transplant, Ali continues to be hopeful about her future. Ali challenges Nick to seize every moment of his life before it's too late. Meanwhile, Nick finds a way to give Ali a new lease on life - even if it means risking one's life and their love for each other.", 'release_year': '2018', 'runtime': '122', 'genres': "['drama', 'romance']", 'production_countries': "['PH']", 'imdb_id': 'tt9060390', 'imdb_score': '6.0', 'imdb_votes': '149.0', 'tmdb_popularity': '1.572', 'tmdb_score': '5.9', 'genres_array': ['drama', 'romance'], 'production_countries_array': ['PH']}
# {'_id': ObjectId('6311590052336cecf29f950a'), 'id': 'tm416134', 'title': 'Fernando Sanjiao: Hombre', 'type': 'MOVIE', 'description': 'Argentine actor and comedian Fernando Sanjiao uses humor and impersonations to explore the concepts of masculinity and fatherhood in modern times.', 'release_year': '2018', 'runtime': '63', 'genres': "['comedy']", 'production_countries': "['AR']", 'imdb_id': 'tt7607332', 'imdb_score': '6.3', 'imdb_votes': '57.0', 'tmdb_popularity': '1.179', 'tmdb_score': '6.5', 'genres_array': ['comedy'], 'production_countries_array': ['AR']}
# {'_id': ObjectId('6311590052336cecf29f950b'), 'id': 'tm448690', 'title': 'Prince of Peoria: A Christmas Moose Miracle', 'type': 'MOVIE', 'description': 'Teddy gets snowed in at a bowling alley, which may cause him to miss the Festival of Lights for the very first time. Fear not, though, because Emil "insists the Christmas moose will save the day.', 'release_year': '2018', 'runtime': '29', 'genres': "['comedy']", 'production_countries': '[]', 'tmdb_popularity': '1.175', 'tmdb_score': '5.8', 'genres_array': ['comedy'], 'production_countries_array': ['']}
# {'_id': ObjectId('6311590052336cecf29f950c'), 'id': 'ts97584', 'title': "Highland: Thailand's Marijuana Awakening", 'type': 'SHOW', 'description': "Thailand's complicated history with marijuana continues to play a role in its policies and laws, as well as the health and security of its citizens.", 'release_year': '2017', 'age_certification': 'TV-MA', 'runtime': '20', 'genres': "['documentation']", 'production_countries': "['US']", 'seasons': '1.0', 'imdb_id': 'tt7201224', 'imdb_score': '6.2', 'imdb_votes': '24.0', 'tmdb_popularity': '0.68', 'tmdb_score': '8.0', 'genres_array': ['documentation'], 'production_countries_array': ['US']}
# {'_id': ObjectId('6311590052336cecf29f950d'), 'id': 'tm369210', 'title': 'Ricardo Quevedo: Hay gente así', 'type': 'MOVIE', 'description': 'Droll comic Ricardo Quevedo hits Bogotá with a set that touches on embarrassing misunderstandings, sex talk, the thrill of being scared and more.', 'release_year': '2018', 'runtime': '58', 'genres': "['comedy']", 'production_countries': "['CO']", 'imdb_id': 'tt7607450', 'imdb_score': '6.3', 'imdb_votes': '104.0', 'tmdb_popularity': '1.279', 'tmdb_score': '7.0', 'genres_array': ['comedy'], 'production_countries_array': ['CO']}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(titles_collection)
# Out:
# {'_id': ObjectId('6311590052336cecf29f8906'), 'id': 'ts300399', 'title': 'Five Came Back: The Reference Films', 'type': 'SHOW', 'description': 'This collection includes 12 World War II-era propaganda films — many of which are graphic and offensive — discussed in the docuseries "Five Came Back."', 'release_year': '1945', 'age_certification': 'TV-MA', 'runtime': '48', 'genres': "['documentation']", 'production_countries': "['US']", 'seasons': '1.0', 'tmdb_popularity': '0.6', 'genres_array': ['documentation'], 'production_countries_array': ['US']}

# %%
from pymongo import MongoClient
from flask import Flask
from bson.json_util import dumps

app = Flask(__name__)

# create connection to mongodb
client = MongoClient("mongodb://localhost:27017")
db = client.six_three_db

# function to convert a string into an array
# input string needs to have comma separated values and must not be empty 
# function expects values will have extra quotes that need to be removed
def convert_arrayish_string(string):
  working_array = []
  strings = string.split(",")
  for str in strings:
    trimmed_str = str.strip(' \"\'')
    working_array.append(trimmed_str)
  return working_array

# find all documents
movies = db.titles.find({})
count = 0

# update each document in the database with a new property "genres_array", which is the genres string converted into an array
for m in movies:
  movie_id = m['id']
  genres_string = m['genres']
  genres_array = convert_arrayish_string(genres_string.strip('[]'))
  countries_string = m['production_countries']
  countries_array = convert_arrayish_string(countries_string.strip('[]'))
  db.titles.update_one({'id': movie_id}, {"$set": {"genres_array": genres_array, "production_countries_array": countries_array}})
  count = count + 1
  
# print the count as a check that all documents were processed
print(count)
# Out:
# 5806
